# %%
# !pwd
# !ls -a
# Out:
# /kaggle/working
# .  ..  __notebook__.ipynb

# %%
# %cd energy_aware_quantization
# Out:
# [Errno 2] No such file or directory: 'energy_aware_quantization'
# /kaggle/working

# %%
# !git pull
# Out:
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
import sys
sys.path.append("/kaggle/working/energy_aware_quantization/src")

# %%
# !cp /kaggle/working/krishna.ipynb /kaggle/working/energy_aware_quantization/notebooks/krishna.ipynb
# !cd /kaggle/working/energy_aware_quantization && git add notebooks/krishna.ipynb && git commit -m "Add Kaggle notebook" && git push origin main
# Out:
# cp: cannot stat '/kaggle/working/krishna.ipynb': No such file or directory
# /bin/bash: line 1: cd: /kaggle/working/energy_aware_quantization: No such file or directory
